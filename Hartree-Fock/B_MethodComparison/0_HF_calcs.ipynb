# %% [markdown]
# # Hartree-Fock: Comparison of optimization algorithms at Best Learning Rate

# %% [markdown]
# Import libreries

# %%
import csv
import pynof
import numpy as np
from scipy.linalg import eigh
import sys
import time as t
# Define energy.py path, in our case is in myCode dir, two directories above
sys.path.insert(1, '../../myCode/')
# read files with optimization functions
from energy import *

# %% [markdown]
#  Molecules definition

# %%
#Molecules Definition
#Times given in Seconds, on Mac M2
#Time for BF3: 120.9061 s
#Time for ALOH: 451.5146 s

# Molecules coordinates
bf3 = pynof.molecule("""
0 1
 F     4.007177     0.908823     0.000000
 F     1.724922     0.908844     0.000000
 F     2.866001    -1.067658    -0.000000
 B     2.866001     0.249991    -0.000000 
""")

chcl3 = pynof.molecule("""
  0 1
Cl        -0.09620       -1.67890        0.13940
Cl        -1.40590        0.92280        0.13940
Cl         1.50220        0.75610        0.13930
C         -0.00010        0.00000       -0.41810
H         -0.00010       -0.00010       -1.51110
""")

aloh = pynof.molecule("""
0 1
Al     0.072995     0.126285    -0.072819
 O    -0.117348     0.068538     1.623683
 O     1.640841     0.345700    -0.695473
 O    -1.181058    -0.017712    -1.213874
 H     2.443051     0.441622    -0.181373
 H    -0.892422    -0.042102     2.172874
 H    -2.121611    -0.146659    -1.103014
""")

# Dictionary to facilitate molecule selection with 
# output file name

molecules = {
    "BF3": bf3,
    "CHCL3": chcl3,
    "ALOH": aloh,
}

# %% [markdown]
# We run the optimization using SD, CG, RMSProp, ADAGRAD and ADAM at the best leraning rate values for comparison. The optimization data is written into a csv files.

# %%
# Dictionary to store time
times  = {}

algorithms = [ 'SD', 'RMSPROP', 'ADAM' ]
#molecule_list = ["BF3","CHCL3","ALOH"]  
molecule_list = ["BF3","ALOH"]  

# Select basis set
basis = "cc-pvdz"

t_st = t.time()
for molecule in molecule_list:
   st=t.time()
   #Define system
   mol = molecules[molecule]
   p = pynof.param(mol,basis)
   p.maxit=10
   
   # File name to store the data
   filename = f"{molecule}.csv"

   with open(filename, mode='w', newline='') as file:
      writer = csv.writer(file)
      writer.writerow(["alg", "iteration", "energy"])  # Header

      for alg in algorithms:
         p.orb_method=alg
         if alg == 'SD':
            p.alpha = 0.02
         elif alg == 'RMSPROP':
            p.alpha = 0.005
         elif alg == 'ADAM':
            p.alpha = 0.02           
         _, energy_data = calc_hf_orbrot(mol, p)
         for i_ext, energy in energy_data:
               writer.writerow([alg, i_ext, energy])
   et = t.time()
   times[molecule]=et-st
t_et = t.time()

#Total start  time
t_et = t.time()

#Print times per molecule
for molecule in molecule_list:
    print(f"Time for {molecule}: {times[molecule]:.4f} s")

print(f"Total Time:",t_et-t_st)
# Out:
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3 entry F          line   228 file /Users/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#     atoms 4   entry B          line   108 file /Users/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#
# Number of basis functions                   (NBF)    = 56
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 16
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 48
# No. of electrons                                     = 32
# Multiplicity                                         = 1
#
# No violations of the orthonormality
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# HF Calculation (SD Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      0     30      0    -433.04856510  -322.48867452 -10432.04856510      8.8e+00    0.0e+00   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      1     30      0    -433.04856510  -322.48867452      0.00000000      8.8e+00    0.0e+00   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      2     30      0    -433.04856510  -322.48867452      0.00000000      8.8e+00    0.0e+00   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      3     30      0    -433.04856510  -322.48867452      0.00000000      8.8e+00    0.0e+00   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 2.9e+01 maxfdiff 1.1e+00
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    2.0000000  -25.81439926
#    2    2.0000000  -25.81287770
#    3    2.0000000  -25.77784825
#    4    2.0000000   -7.94674953
#    5    2.0000000   -1.34286431
#    6    2.0000000   -1.23899846
#    7    2.0000000   -1.23896873
#    8    2.0000000   -0.91166317
#    9    2.0000000   -0.90816286
#   10    2.0000000   -0.90813101
#   11    2.0000000   -0.57493245
#   12    2.0000000   -0.56458631
#   13    2.0000000   -0.56444839
#   14    2.0000000   -0.53724907
#   15    2.0000000   -0.53722109
#   16    2.0000000   -0.49795751
#   17    0.0000000    0.00000000
#   18    0.0000000    0.00000000
#   19    0.0000000    0.00000000
#   20    0.0000000    0.00000000
#   21    0.0000000    0.00000000
#   22    0.0000000    0.00000000
#   23    0.0000000    0.00000000
#   24    0.0000000    0.00000000
#   25    0.0000000    0.00000000
#   26    0.0000000    0.00000000
#   27    0.0000000    0.00000000
#   28    0.0000000    0.00000000
#   29    0.0000000    0.00000000
#   30    0.0000000    0.00000000
#   31    0.0000000    0.00000000
#   32    0.0000000    0.00000000
#   33    0.0000000    0.00000000
#   34    0.0000000    0.00000000
#   35    0.0000000    0.00000000
#   36    0.0000000    0.00000000
#   37    0.0000000    0.00000000
#   38    0.0000000    0.00000000
#   39    0.0000000    0.00000000
#   40    0.0000000    0.00000000
#   41    0.0000000    0.00000000
#   42    0.0000000    0.00000000
#   43    0.0000000    0.00000000
#   44    0.0000000    0.00000000
#   45    0.0000000    0.00000000
#   46    0.0000000    0.00000000
#   47    0.0000000    0.00000000
#   48    0.0000000    0.00000000
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -322.4886745
#
#
# Elapsed Time:      26.73 (Seconds)
# True
# Number of basis functions                   (NBF)    = 56
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 16
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 48
# No. of electrons                                     = 32
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# HF Calculation (RMSPROP Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.005
#      0     30      0    -428.10764781  -317.54775723 -10427.10764781      8.1e+00    0.0e+00   False   True
# alpha =  0.005
#      1     30      0    -432.96577325  -322.40588267     -4.85812544      4.6e+00    0.0e+00   False   True
# alpha =  0.005
#      2     30      0    -433.64683636  -323.08694578     -0.68106310      3.7e+00    0.0e+00   False   True
# alpha =  0.005
#      3     30      0    -433.69384490  -323.13395432     -0.04700854      3.2e+00    0.0e+00   False   True
# alpha =  0.005
#      4     30      0    -433.71016969  -323.15027911     -0.01632479      2.9e+00    0.0e+00   False   True
# alpha =  0.005
#      5     30      0    -433.72588298  -323.16599240     -0.01571329      2.4e+00    0.0e+00   False   True
# alpha =  0.005
#      6     30      0    -433.73770573  -323.17781515     -0.01182276      1.9e+00    0.0e+00   False   True
# alpha =  0.005
#      7     30      0    -433.74512908  -323.18523850     -0.00742335      1.5e+00    0.0e+00   False   True
# alpha =  0.005
#      8     30      0    -433.74512908  -323.18523850      0.00000000      1.5e+00    0.0e+00   False   True
# alpha =  0.005
#      9     30      0    -433.74512908  -323.18523850      0.00000000      1.5e+00    0.0e+00   False   True
#
# Lagrage sumdiff 9.5e+00 maxfdiff 8.4e-02
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    2.0000000  -26.32121229
#    2    2.0000000  -26.29861351
#    3    2.0000000  -26.29279561
#    4    2.0000000   -7.81058934
#    5    2.0000000   -1.39537321
#    6    2.0000000   -1.30695785
#    7    2.0000000   -1.29833728
#    8    2.0000000   -1.11351027
#    9    2.0000000   -1.09004102
#   10    2.0000000   -1.07685924
#   11    2.0000000   -0.75497491
#   12    2.0000000   -0.74561710
#   13    2.0000000   -0.73610812
#   14    2.0000000   -0.73491881
#   15    2.0000000   -0.70931986
#   16    2.0000000   -0.70642662
#   17    0.0000000    0.00000000
#   18    0.0000000    0.00000000
#   19    0.0000000    0.00000000
#   20    0.0000000    0.00000000
#   21    0.0000000    0.00000000
#   22    0.0000000    0.00000000
#   23    0.0000000    0.00000000
#   24    0.0000000    0.00000000
#   25    0.0000000    0.00000000
#   26    0.0000000    0.00000000
#   27    0.0000000    0.00000000
#   28    0.0000000    0.00000000
#   29    0.0000000    0.00000000
#   30    0.0000000    0.00000000
#   31    0.0000000    0.00000000
#   32    0.0000000    0.00000000
#   33    0.0000000    0.00000000
#   34    0.0000000    0.00000000
#   35    0.0000000    0.00000000
#   36    0.0000000    0.00000000
#   37    0.0000000    0.00000000
#   38    0.0000000    0.00000000
#   39    0.0000000    0.00000000
#   40    0.0000000    0.00000000
#   41    0.0000000    0.00000000
#   42    0.0000000    0.00000000
#   43    0.0000000    0.00000000
#   44    0.0000000    0.00000000
#   45    0.0000000    0.00000000
#   46    0.0000000    0.00000000
#   47    0.0000000    0.00000000
#   48    0.0000000    0.00000000
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -323.1852385
#
#
# Elapsed Time:      63.40 (Seconds)
# True
# Number of basis functions                   (NBF)    = 56
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 16
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 48
# No. of electrons                                     = 32
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# HF Calculation (ADAM Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
#      0     30      0    -433.25478607  -322.69489549 -10432.25478607      2.6e+00    0.0e+00   False   True
# alpha =  0.02
#      1     30      0    -433.76063360  -323.20074302     -0.50584753      5.6e-02    0.0e+00   False   True
# alpha =  0.02
#      2     30      0    -433.76066060  -323.20077002     -0.00002700      4.9e-02    0.0e+00   False   True
# alpha =  0.02
#      3     30      0    -433.76066060  -323.20077002      0.00000000      4.9e-02    0.0e+00   False   True
# alpha =  0.02
#      4     30      0    -433.76066060  -323.20077002      0.00000000      4.9e-02    0.0e+00   False   True
# alpha =  0.02
#      5     30      0    -433.76066060  -323.20077002      0.00000000      4.9e-02    0.0e+00   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 3.5e-01 maxfdiff 4.3e-03
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    2.0000000  -26.29820439
#    2    2.0000000  -26.29731968
#    3    2.0000000  -26.29053223
#    4    2.0000000   -7.80436440
#    5    2.0000000   -1.49651940
#    6    2.0000000   -1.34001369
#    7    2.0000000   -1.33185579
#    8    2.0000000   -1.11073503
#    9    2.0000000   -1.10602122
#   10    2.0000000   -1.08601515
#   11    2.0000000   -0.75737767
#   12    2.0000000   -0.75079321
#   13    2.0000000   -0.74835163
#   14    2.0000000   -0.68314895
#   15    2.0000000   -0.68276970
#   16    2.0000000   -0.67638345
#   17    0.0000000    0.00000000
#   18    0.0000000    0.00000000
#   19    0.0000000    0.00000000
#   20    0.0000000    0.00000000
#   21    0.0000000    0.00000000
#   22    0.0000000    0.00000000
#   23    0.0000000    0.00000000
#   24    0.0000000    0.00000000
#   25    0.0000000    0.00000000
#   26    0.0000000    0.00000000
#   27    0.0000000    0.00000000
#   28    0.0000000    0.00000000
#   29    0.0000000    0.00000000
#   30    0.0000000    0.00000000
#   31    0.0000000    0.00000000
#   32    0.0000000    0.00000000
#   33    0.0000000    0.00000000
#   34    0.0000000    0.00000000
#   35    0.0000000    0.00000000
#   36    0.0000000    0.00000000
#   37    0.0000000    0.00000000
#   38    0.0000000    0.00000000
#   39    0.0000000    0.00000000
#   40    0.0000000    0.00000000
#   41    0.0000000    0.00000000
#   42    0.0000000    0.00000000
#   43    0.0000000    0.00000000
#   44    0.0000000    0.00000000
#   45    0.0000000    0.00000000
#   46    0.0000000    0.00000000
#   47    0.0000000    0.00000000
#   48    0.0000000    0.00000000
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -323.2007700
#
#
# Elapsed Time:      30.75 (Seconds)
# True
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry AL         line   418 file /Users/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-4 entry O          line   198 file /Users/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#     atoms 5-7 entry H          line    22 file /Users/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#
# Number of basis functions                   (NBF)    = 75
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 20
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 60
# No. of electrons                                     = 40
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# HF Calculation (SD Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      0     30      0    -628.63473257  -467.92312463 -10627.63473257      5.7e+00    0.0e+00   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      1     30      0    -628.63473257  -467.92312463      0.00000000      5.7e+00    0.0e+00   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      2     30      0    -628.63473257  -467.92312463      0.00000000      5.7e+00    0.0e+00   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      3     30      0    -628.63473257  -467.92312463      0.00000000      5.7e+00    0.0e+00   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 3.2e+01 maxfdiff 4.8e-01
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    2.0000000  -32.73236231
#    2    2.0000000  -22.15656632
#    3    2.0000000  -22.04108702
#    4    2.0000000  -21.90423834
#    5    2.0000000   -7.57349099
#    6    2.0000000   -6.90711273
#    7    2.0000000   -6.89250342
#    8    2.0000000   -5.49890444
#    9    2.0000000   -3.01520641
#   10    2.0000000   -3.00790304
#   11    2.0000000   -2.99346030
#   12    2.0000000   -1.23090438
#   13    2.0000000   -1.14518786
#   14    2.0000000   -0.99262245
#   15    2.0000000   -0.64788298
#   16    2.0000000   -0.63758718
#   17    2.0000000   -0.60725994
#   18    2.0000000   -0.44518102
#   19    2.0000000   -0.43761143
#   20    2.0000000   -0.42095657
#   21    0.0000000    0.00000000
#   22    0.0000000    0.00000000
#   23    0.0000000    0.00000000
#   24    0.0000000    0.00000000
#   25    0.0000000    0.00000000
#   26    0.0000000    0.00000000
#   27    0.0000000    0.00000000
#   28    0.0000000    0.00000000
#   29    0.0000000    0.00000000
#   30    0.0000000    0.00000000
#   31    0.0000000    0.00000000
#   32    0.0000000    0.00000000
#   33    0.0000000    0.00000000
#   34    0.0000000    0.00000000
#   35    0.0000000    0.00000000
#   36    0.0000000    0.00000000
#   37    0.0000000    0.00000000
#   38    0.0000000    0.00000000
#   39    0.0000000    0.00000000
#   40    0.0000000    0.00000000
#   41    0.0000000    0.00000000
#   42    0.0000000    0.00000000
#   43    0.0000000    0.00000000
#   44    0.0000000    0.00000000
#   45    0.0000000    0.00000000
#   46    0.0000000    0.00000000
#   47    0.0000000    0.00000000
#   48    0.0000000    0.00000000
#   49    0.0000000    0.00000000
#   50    0.0000000    0.00000000
#   51    0.0000000    0.00000000
#   52    0.0000000    0.00000000
#   53    0.0000000    0.00000000
#   54    0.0000000    0.00000000
#   55    0.0000000    0.00000000
#   56    0.0000000    0.00000000
#   57    0.0000000    0.00000000
#   58    0.0000000    0.00000000
#   59    0.0000000    0.00000000
#   60    0.0000000    0.00000000
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -467.9231246
#
#
# Elapsed Time:     111.66 (Seconds)
# True
# Number of basis functions                   (NBF)    = 75
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 20
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 60
# No. of electrons                                     = 40
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# HF Calculation (RMSPROP Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.005
#      0     30      0    -624.95849157  -464.24688363 -10623.95849157      8.3e+00    0.0e+00   False   True
# alpha =  0.005
#      1     30      0    -628.36429575  -467.65268781     -3.40580418      6.4e+00    0.0e+00   False   True
# alpha =  0.005
#      2     30      0    -628.97405161  -468.26244367     -0.60975586      5.8e+00    0.0e+00   False   True
# alpha =  0.005
#      3     30      0    -629.03233906  -468.32073112     -0.05828746      5.2e+00    0.0e+00   False   True
# alpha =  0.005
#      4     30      0    -629.04944669  -468.33783875     -0.01710763      4.9e+00    0.0e+00   False   True
# alpha =  0.005
#      5     30      0    -629.06962963  -468.35802169     -0.02018294      4.3e+00    0.0e+00   False   True
# alpha =  0.005
#      6     30      0    -629.09052796  -468.37892002     -0.02089832      3.5e+00    0.0e+00   False   True
# alpha =  0.005
#      7     30      0    -629.10520051  -468.39359257     -0.01467256      2.9e+00    0.0e+00   False   True
# alpha =  0.005
#      8     30      0    -629.11466374  -468.40305580     -0.00946323      2.3e+00    0.0e+00   False   True
# alpha =  0.005
#      9     30      0    -629.11595051  -468.40434257     -0.00128677      1.8e+00    0.0e+00   False   True
#
# Lagrage sumdiff 1.3e+01 maxfdiff 1.5e-01
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    2.0000000  -58.46365860
#    2    2.0000000  -20.52682943
#    3    2.0000000  -20.51024567
#    4    2.0000000  -20.50403562
#    5    2.0000000   -4.92824011
#    6    2.0000000   -3.22061272
#    7    2.0000000   -3.21425077
#    8    2.0000000   -3.21356901
#    9    2.0000000   -0.95629073
#   10    2.0000000   -0.94163466
#   11    2.0000000   -0.93935885
#   12    2.0000000   -0.93168219
#   13    2.0000000   -0.92612684
#   14    2.0000000   -0.91259028
#   15    2.0000000   -0.63271826
#   16    2.0000000   -0.62525257
#   17    2.0000000   -0.62026392
#   18    2.0000000   -0.53759523
#   19    2.0000000   -0.52563004
#   20    2.0000000   -0.52166596
#   21    0.0000000    0.00000000
#   22    0.0000000    0.00000000
#   23    0.0000000    0.00000000
#   24    0.0000000    0.00000000
#   25    0.0000000    0.00000000
#   26    0.0000000    0.00000000
#   27    0.0000000    0.00000000
#   28    0.0000000    0.00000000
#   29    0.0000000    0.00000000
#   30    0.0000000    0.00000000
#   31    0.0000000    0.00000000
#   32    0.0000000    0.00000000
#   33    0.0000000    0.00000000
#   34    0.0000000    0.00000000
#   35    0.0000000    0.00000000
#   36    0.0000000    0.00000000
#   37    0.0000000    0.00000000
#   38    0.0000000    0.00000000
#   39    0.0000000    0.00000000
#   40    0.0000000    0.00000000
#   41    0.0000000    0.00000000
#   42    0.0000000    0.00000000
#   43    0.0000000    0.00000000
#   44    0.0000000    0.00000000
#   45    0.0000000    0.00000000
#   46    0.0000000    0.00000000
#   47    0.0000000    0.00000000
#   48    0.0000000    0.00000000
#   49    0.0000000    0.00000000
#   50    0.0000000    0.00000000
#   51    0.0000000    0.00000000
#   52    0.0000000    0.00000000
#   53    0.0000000    0.00000000
#   54    0.0000000    0.00000000
#   55    0.0000000    0.00000000
#   56    0.0000000    0.00000000
#   57    0.0000000    0.00000000
#   58    0.0000000    0.00000000
#   59    0.0000000    0.00000000
#   60    0.0000000    0.00000000
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -468.4043426
#
#
# Elapsed Time:     203.17 (Seconds)
# True
# Number of basis functions                   (NBF)    = 75
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 20
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 60
# No. of electrons                                     = 40
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# HF Calculation (ADAM Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
#      0     30      0    -628.70942236  -467.99781442 -10627.70942236      1.8e+00    0.0e+00   False   True
# alpha =  0.02
#      1     30      0    -629.13643433  -468.42482639     -0.42701196      7.5e-02    0.0e+00   False   True
# alpha =  0.02
#      2     30      0    -629.13644169  -468.42483375     -0.00000736      8.1e-02    0.0e+00   False   True
# alpha =  0.02
#      3     30      0    -629.13644867  -468.42484073     -0.00000698      7.4e-02    0.0e+00   False   True
# alpha =  0.02
#      4     30      0    -629.13644867  -468.42484073      0.00000000      7.4e-02    0.0e+00   False   True
# alpha =  0.02
#      5     30      0    -629.13644867  -468.42484073      0.00000000      7.4e-02    0.0e+00   False   True
# alpha =  0.02
#      6     30      0    -629.13644867  -468.42484073      0.00000000      7.4e-02    0.0e+00   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 7.1e-01 maxfdiff 5.6e-03
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    2.0000000  -58.43580886
#    2    2.0000000  -20.48288564
#    3    2.0000000  -20.47521823
#    4    2.0000000  -20.46526606
#    5    2.0000000   -4.94566478
#    6    2.0000000   -3.22759360
#    7    2.0000000   -3.21971615
#    8    2.0000000   -3.21929267
#    9    2.0000000   -0.97773525
#   10    2.0000000   -0.97349444
#   11    2.0000000   -0.96398750
#   12    2.0000000   -0.94855598
#   13    2.0000000   -0.94627646
#   14    2.0000000   -0.94468926
#   15    2.0000000   -0.63211199
#   16    2.0000000   -0.62509241
#   17    2.0000000   -0.61476913
#   18    2.0000000   -0.53437408
#   19    2.0000000   -0.52825046
#   20    2.0000000   -0.51818952
#   21    0.0000000    0.00000000
#   22    0.0000000    0.00000000
#   23    0.0000000    0.00000000
#   24    0.0000000    0.00000000
#   25    0.0000000    0.00000000
#   26    0.0000000    0.00000000
#   27    0.0000000    0.00000000
#   28    0.0000000    0.00000000
#   29    0.0000000    0.00000000
#   30    0.0000000    0.00000000
#   31    0.0000000    0.00000000
#   32    0.0000000    0.00000000
#   33    0.0000000    0.00000000
#   34    0.0000000    0.00000000
#   35    0.0000000    0.00000000
#   36    0.0000000    0.00000000
#   37    0.0000000    0.00000000
#   38    0.0000000    0.00000000
#   39    0.0000000    0.00000000
#   40    0.0000000    0.00000000
#   41    0.0000000    0.00000000
#   42    0.0000000    0.00000000
#   43    0.0000000    0.00000000
#   44    0.0000000    0.00000000
#   45    0.0000000    0.00000000
#   46    0.0000000    0.00000000
#   47    0.0000000    0.00000000
#   48    0.0000000    0.00000000
#   49    0.0000000    0.00000000
#   50    0.0000000    0.00000000
#   51    0.0000000    0.00000000
#   52    0.0000000    0.00000000
#   53    0.0000000    0.00000000
#   54    0.0000000    0.00000000
#   55    0.0000000    0.00000000
#   56    0.0000000    0.00000000
#   57    0.0000000    0.00000000
#   58    0.0000000    0.00000000
#   59    0.0000000    0.00000000
#   60    0.0000000    0.00000000
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -468.4248407
#
#
# Elapsed Time:     136.64 (Seconds)
# True
# Time for BF3: 120.9061 s
# Time for ALOH: 451.5146 s
# Total Time: 572.4209339618683
