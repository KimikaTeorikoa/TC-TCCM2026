# %% [markdown]
# # Natural Orbital Functionals: Method Comparison at 0.02 and 0.002 step size

# %% [markdown]
# Import libreries

# %%
from scipy.linalg import eigh
import pynof
import numpy as np
import csv
import sys
import time as t
# Define energy.py path, in our case is in myCode dir, two directories above
sys.path.insert(1, '../../myCode/')
# read files with optimization functions
from energy import *

# %% [markdown]
# Create molecule and choose basis set

# %%
# Molecules definition
#Time for CO2: 457.8015 s
#Time for CO: 379.3235 s
#Time for H2O: 353.4587 s
#Total Time: 1190.5839891433716

co = pynof.molecule("""
0 1
  C      0.0       0.0         0.0
  O      0.0       0.0         1.12     
""")

co2 = pynof.molecule("""
0 1
C    0.0000    0.0000    0.0000   
O    1.1000    0.0000    0.0000   
O    -1.1000   -0.0000    0.0000 
""")

h2o = pynof.molecule("""
0 1
  O  0.0000   0.000   0.116
  H  0.0000   0.749  -0.453
  H  0.0000  -0.749  -0.453
""")

# Dictionary to facilitate molecule selection with 
# output file name

molecules = {
    "CO": co,
    "CO2": co2,
    "H2O": h2o,
}

# %% [markdown]
# Run NOF calculations with several optimization algorithms at 0.002 step size.

# %%
times = {} 
#molecule_list = ["CO2","CO","H2O"]
molecule_list = ["CO","H2O"]

alpha_list=[0.02,0.002]

t_st=t.time()
for molecule in molecule_list:
    st=t.time()
    for alpha in alpha_list:  
        mol = molecules[molecule]

        # Select basis set
        basis = "cc-pvdz"

        p = pynof.param(mol,basis)

        # Here we select the NOF functional.
        p.maxit = 25
        p.alpha = alpha

        algorithms = [ 'SD', 'RMSPROP', 'ADAM' ]

        # File name to store the data
        filename = f"{molecule}_{p.alpha}.csv"

        with open(filename, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["alg", "iteration", "energy"])  # Header

            for alg in algorithms:
                p.orb_method=alg
                _, energy_data = calc_nof_orbrot(mol, p)
                for i_ext, energy in energy_data:
                    writer.writerow([alg, i_ext, energy])
    et=t.time()
    times[molecule] = et - st
t_et=t.time()  

for molecule in molecule_list:
     print(f"Time for {molecule}: {times[molecule]:.4f} s")

print(f"Total Time:",t_et-t_st)
# Out:
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   138 file /home/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry O          line   198 file /home/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#
# Number of basis functions                   (NBF)    = 42
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 11
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 33
# No. of electrons                                     = 22
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (SD/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      0     30     58    -247.88240863  -186.30542412 -10246.88240863      2.8e+00    4.1e-03   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#   22    0.0155600   -0.03207775
#   23    0.0071967   -0.01695846
#   24    0.0014752   -0.00354867
#   25    0.0014752   -0.00354855
#   26    0.0020284   -0.00562036
#   27    0.0020278   -0.00561870
#   28    0.0001735   -0.00235685
#   29    0.0000834   -0.00114523
#   30    0.0000711   -0.00156256
#   31    0.0000379   -0.00080377
#   32    0.0000633   -0.00141536
#   33    0.0000382   -0.00080837
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -187.9932259
#
#
# Elapsed Time:      92.36 (Seconds)
# True
# Number of basis functions                   (NBF)    = 42
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 11
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 33
# No. of electrons                                     = 22
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (RMSPROP/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
#      0     30     72    -248.56023558  -186.98325107 -10247.56023558      6.9e+00    7.6e-03   False   True
# alpha =  0.02
#      1     30     35    -249.39305891  -187.81607440     -0.83282333      4.4e+00    2.5e-05   False   True
# alpha =  0.02
#      2     30     36    -249.48034171  -187.90335720     -0.08728280      3.4e+00    1.7e-05   False   True
# alpha =  0.02
#      3     30     37    -249.53837114  -187.96138662     -0.05802942      2.2e+00    1.7e-05   False   True
# alpha =  0.02
#      4     30     32    -249.56388126  -187.98689674     -0.02551012      1.9e+00    2.2e-05   False   True
# alpha =  0.02
#      5     30      0    -249.56402797  -187.98704345     -0.00014671      1.9e+00    2.2e-05   False   True
# alpha =  0.02
#      6     30      0    -249.56402797  -187.98704345      0.00000000      1.9e+00    2.2e-05   False   True
# alpha =  0.02
#      7     30      0    -249.56402797  -187.98704345      0.00000000      1.9e+00    2.2e-05   False   True
# alpha =  0.02
#      8     30      0    -249.56402797  -187.98704345      0.00000000      1.9e+00    2.2e-05   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 1.3e+01 maxfdiff 9.0e-02
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    1.9999262  -20.57902809
#    2    1.9999359  -20.57681945
#    3    1.9996436  -11.42666309
#    4    1.9932749   -1.53449863
#    5    1.9929568   -1.51406800
#    6    1.9847352   -0.78291681
#    7    1.9829448   -0.75708068
#    8    1.9776961   -0.68667250
#    9    1.9765424   -0.64973271
#   10    1.9665689   -0.62766730
#   11    1.9668166   -0.60145049
#   12    0.0297791   -0.04625970
#   13    0.0034043   -0.00726949
#   14    0.0298859   -0.04633324
#   15    0.0035453   -0.00736990
#   16    0.0193147   -0.03292949
#   17    0.0041428   -0.00850911
#   18    0.0163636   -0.02872648
#   19    0.0059403   -0.01086434
#   20    0.0097049   -0.01524634
#   21    0.0073502   -0.01281165
#   22    0.0086412   -0.01395240
#   23    0.0066236   -0.01159448
#   24    0.0038832   -0.00893188
#   25    0.0031600   -0.00785217
#   26    0.0034499   -0.00835064
#   27    0.0032751   -0.00810429
#   28    0.0001817   -0.00249740
#   29    0.0001747   -0.00239547
#   30    0.0000432   -0.00090095
#   31    0.0000209   -0.00044729
#   32    0.0000416   -0.00087761
#   33    0.0000322   -0.00068792
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -187.9870435
#
#
# Elapsed Time:      32.68 (Seconds)
# True
# Number of basis functions                   (NBF)    = 42
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 11
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 33
# No. of electrons                                     = 22
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (ADAM/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
#      0     30     62    -248.90066952  -187.32368501 -10247.90066952      1.6e+00    6.4e-03   False   True
# alpha =  0.02
#      1     30     29    -249.64268602  -188.06570150     -0.74201649      7.5e-02    2.0e-05   False   True
# alpha =  0.02
#      2     30     34    -249.65718859  -188.08020408     -0.01450258      6.5e-02    2.0e-05   False   True
# alpha =  0.02
#      3     30     23    -249.65889115  -188.08190664     -0.00170256      6.5e-02    1.6e-05   False   True
# alpha =  0.02
#      4     30     14    -249.65954886  -188.08256435     -0.00065771      6.5e-02    2.4e-05   False   True
# alpha =  0.02
#      5     30     20    -249.65991947  -188.08293496     -0.00037061      2.9e-02    1.4e-05   False   True
# alpha =  0.02
#      6     30     18    -249.66013170  -188.08314719     -0.00021223      2.7e-02    1.5e-05   False   True
# alpha =  0.02
#      7     30     11    -249.66022532  -188.08324081     -0.00009362      3.3e-02    2.5e-05   False   True
# alpha =  0.02
#      8     30     15    -249.66024714  -188.08326263     -0.00002182      2.9e-02    2.4e-05   False   True
# alpha =  0.02
#      9     30      4    -249.66025319  -188.08326868     -0.00000605      3.2e-02    2.0e-05   False   True
# alpha =  0.02
#     10     30     11    -249.66025639  -188.08327188     -0.00000320      3.5e-02    1.9e-05   False   True
# alpha =  0.02
#     11     30      3    -249.66026087  -188.08327635     -0.00000448      2.9e-02    1.9e-05   False   True
# alpha =  0.02
#     12     30      4    -249.66026116  -188.08327664     -0.00000029      2.8e-02    1.5e-05   False   True
# alpha =  0.02
#     13     30      0    -249.66026129  -188.08327677     -0.00000013      2.8e-02    1.5e-05   False   True
# alpha =  0.02
#     14     30      0    -249.66026129  -188.08327677      0.00000000      2.8e-02    1.5e-05   False   True
# alpha =  0.02
#     15     30      0    -249.66026129  -188.08327677      0.00000000      2.8e-02    1.5e-05   False   True
# alpha =  0.02
#     16     30      0    -249.66026129  -188.08327677      0.00000000      2.8e-02    1.5e-05   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 1.7e-01 maxfdiff 3.4e-03
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    1.9999355  -20.65217050
#    2    1.9999275  -20.65206986
#    3    1.9996439  -11.41154786
#    4    1.9925474   -1.55583406
#    5    1.9929241   -1.53094190
#    6    1.9841064   -0.79735875
#    7    1.9831320   -0.78052755
#    8    1.9754489   -0.73076401
#    9    1.9781098   -0.69140742
#   10    1.9672054   -0.63815910
#   11    1.9664497   -0.63052403
#   12    0.0300153   -0.04683721
#   13    0.0035349   -0.00738793
#   14    0.0299330   -0.04649722
#   15    0.0028616   -0.00671184
#   16    0.0155459   -0.02741909
#   17    0.0063443   -0.01154582
#   18    0.0206334   -0.03591210
#   19    0.0039176   -0.00816969
#   20    0.0094059   -0.01495103
#   21    0.0074622   -0.01328859
#   22    0.0102252   -0.01569672
#   23    0.0056683   -0.01051720
#   24    0.0039729   -0.00910895
#   25    0.0031030   -0.00775011
#   26    0.0037767   -0.00859335
#   27    0.0036758   -0.00886563
#   28    0.0001786   -0.00245033
#   29    0.0001775   -0.00243335
#   30    0.0000414   -0.00087184
#   31    0.0000311   -0.00067074
#   32    0.0000395   -0.00083281
#   33    0.0000250   -0.00052750
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -188.0832768
#
#
# Elapsed Time:      63.73 (Seconds)
# True
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   138 file /home/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry O          line   198 file /home/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#
# Number of basis functions                   (NBF)    = 42
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 11
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 33
# No. of electrons                                     = 22
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (SD/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      0     30     75    -243.00096701  -181.42398249 -10242.00096701      8.7e+00    3.1e-03   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#   19    0.0042818   -0.00868438
#   20    0.0061491   -0.00860650
#   21    0.0051884   -0.00751939
#   22    0.0195587   -0.03830036
#   23    0.0068400   -0.01569580
#   24    0.0023537   -0.00523040
#   25    0.0023535   -0.00523014
#   26    0.0022851   -0.00573612
#   27    0.0022846   -0.00573464
#   28    0.0002058   -0.00264899
#   29    0.0000953   -0.00123559
#   30    0.0000606   -0.00133792
#   31    0.0000587   -0.00122140
#   32    0.0000775   -0.00168430
#   33    0.0000592   -0.00123869
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -186.5138617
#
#
# Elapsed Time:      91.17 (Seconds)
# True
# Number of basis functions                   (NBF)    = 42
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 11
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 33
# No. of electrons                                     = 22
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (RMSPROP/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.002
#      0     30     82    -241.43821963  -179.86123511 -10240.43821963      9.3e+00    6.8e-03   False   True
# alpha =  0.002
#      1     30     61    -244.61465720  -183.03767269     -3.17643758      6.9e+00    2.1e-05   False   True
# alpha =  0.002
#      2     30     43    -246.56822303  -184.99123852     -1.95356583      5.2e+00    1.7e-05   False   True
# alpha =  0.002
#      3     30     38    -247.79088783  -186.21390331     -1.22266479      3.9e+00    1.5e-05   False   True
# alpha =  0.002
#      4     30     24    -248.65557830  -187.07859378     -0.86469047      2.8e+00    1.8e-05   False   True
# alpha =  0.002
#      5     30     18    -249.10232004  -187.52533553     -0.44674175      2.1e+00    2.4e-05   False   True
# alpha =  0.002
#      6     30     30    -249.35176968  -187.77478516     -0.24944963      1.6e+00    1.5e-05   False   True
# alpha =  0.002
#      7     30     28    -249.49252569  -187.91554117     -0.14075601      1.3e+00    1.2e-05   False   True
# alpha =  0.002
#      8     30     19    -249.57147634  -187.99449183     -0.07895066      1.0e+00    2.0e-05   False   True
# alpha =  0.002
#      9     30     24    -249.61449127  -188.03750676     -0.04301493      8.9e-01    2.2e-05   False   True
# alpha =  0.002
#     10     30     19    -249.63753676  -188.06055225     -0.02304549      8.6e-01    2.5e-05   False   True
# alpha =  0.002
#     11     30     19    -249.64686826  -188.06988374     -0.00933149      8.3e-01    2.0e-05   False   True
# alpha =  0.002
#     12     30     22    -249.65009391  -188.07310940     -0.00322565      7.8e-01    1.2e-05   False   True
# alpha =  0.002
#     13     30     14    -249.65167725  -188.07469274     -0.00158334      7.3e-01    1.9e-05   False   True
# alpha =  0.002
#     14     30      6    -249.65319226  -188.07620774     -0.00151500      6.4e-01    2.1e-05   False   True
# alpha =  0.002
#     15     30     12    -249.65431362  -188.07732910     -0.00112136      5.4e-01    2.3e-05   False   True
# alpha =  0.002
#     16     30     14    -249.65552533  -188.07854082     -0.00121172      4.0e-01    1.2e-05   False   True
# alpha =  0.002
#     17     30     14    -249.65613263  -188.07914811     -0.00060730      2.8e-01    1.6e-05   False   True
# alpha =  0.002
#     18     30      6    -249.65684333  -188.07985882     -0.00071070      1.9e-01    2.4e-05   False   True
# alpha =  0.002
#     19     30      6    -249.65723183  -188.08024731     -0.00038849      1.6e-01    2.1e-05   False   True
# alpha =  0.002
#     20     30     13    -249.65762226  -188.08063775     -0.00039044      1.4e-01    1.7e-05   False   True
# alpha =  0.002
#     21     30      0    -249.65762576  -188.08064125     -0.00000350      1.4e-01    1.7e-05   False   True
# alpha =  0.002
#     22     30      0    -249.65762576  -188.08064125      0.00000000      1.4e-01    1.7e-05   False   True
# alpha =  0.002
#     23     30      0    -249.65762576  -188.08064125      0.00000000      1.4e-01    1.7e-05   False   True
# alpha =  0.002
#     24     30      0    -249.65762576  -188.08064125      0.00000000      1.4e-01    1.7e-05   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 9.6e-01 maxfdiff 8.0e-03
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    1.9999448  -20.64684162
#    2    1.9999179  -20.64652975
#    3    1.9996490  -11.41166170
#    4    1.9931683   -1.54993034
#    5    1.9921957   -1.45545038
#    6    1.9762152   -0.84399642
#    7    1.9835395   -0.78864408
#    8    1.9835640   -0.70815884
#    9    1.9780607   -0.68956769
#   10    1.9683960   -0.68078818
#   11    1.9667362   -0.62617078
#   12    0.0297531   -0.04652456
#   13    0.0035108   -0.00738797
#   14    0.0284509   -0.04558096
#   15    0.0031530   -0.00712977
#   16    0.0175113   -0.03021344
#   17    0.0044280   -0.00870243
#   18    0.0085258   -0.01351527
#   19    0.0079102   -0.01336444
#   20    0.0089759   -0.01445440
#   21    0.0074847   -0.01319964
#   22    0.0204614   -0.03580404
#   23    0.0033234   -0.00753343
#   24    0.0044024   -0.00929728
#   25    0.0034020   -0.00812817
#   26    0.0038797   -0.00906198
#   27    0.0029520   -0.00748673
#   28    0.0001828   -0.00249272
#   29    0.0001682   -0.00230099
#   30    0.0000439   -0.00092579
#   31    0.0000382   -0.00081461
#   32    0.0000340   -0.00071615
#   33    0.0000212   -0.00045179
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -188.0806412
#
#
# Elapsed Time:      88.31 (Seconds)
# True
# Number of basis functions                   (NBF)    = 42
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 11
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 2
# Dimension of the Nat. Orb. subspace         (NBF5)   = 33
# No. of electrons                                     = 22
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (ADAM/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.002
#      0     30     75    -241.06455670  -179.48757218 -10240.06455670      9.6e+00    9.6e-03   False   True
# alpha =  0.002
#      1     30     63    -244.13015825  -182.55317373     -3.06560155      7.0e+00    1.8e-05   False   True
# alpha =  0.002
#      2     30     53    -246.07954721  -184.50256269     -1.94938896      5.5e+00    2.1e-05   False   True
# alpha =  0.002
#      3     30     49    -247.41222754  -185.83524303     -1.33268034      4.2e+00    1.3e-05   False   True
# alpha =  0.002
#      4     30     31    -248.40351875  -186.82653423     -0.99129120      3.1e+00    1.6e-05   False   True
# alpha =  0.002
#      5     30     37    -248.92413276  -187.34714824     -0.52061401      2.2e+00    2.2e-05   False   True
# alpha =  0.002
#      6     30     31    -249.20804957  -187.63106505     -0.28391681      1.5e+00    2.5e-05   False   True
# alpha =  0.002
#      7     30     28    -249.37083588  -187.79385137     -0.16278632      1.1e+00    1.5e-05   False   True
# alpha =  0.002
#      8     30     32    -249.47172649  -187.89474198     -0.10089061      8.5e-01    1.6e-05   False   True
# alpha =  0.002
#      9     30     33    -249.53562827  -187.95864375     -0.06390177      6.5e-01    2.1e-05   False   True
# alpha =  0.002
#     10     30     27    -249.57499632  -187.99801180     -0.03936805      4.9e-01    2.0e-05   False   True
# alpha =  0.002
#     11     30     39    -249.60156348  -188.02457896     -0.02656716      3.8e-01    1.3e-05   False   True
# alpha =  0.002
#     12     30     30    -249.62073514  -188.04375063     -0.01917166      2.6e-01    1.5e-05   False   True
# alpha =  0.002
#     13     30     26    -249.63279259  -188.05580807     -0.01205745      1.5e-01    1.7e-05   False   True
# alpha =  0.002
#     14     30     26    -249.63891883  -188.06193432     -0.00612625      5.3e-02    1.7e-05   False   True
# alpha =  0.002
#     15     30     16    -249.64155840  -188.06457388     -0.00263956      1.4e-02    2.7e-05   False   True
# alpha =  0.002
#     16     30     20    -249.64338795  -188.06640343     -0.00182955      1.4e-02    1.4e-05   False   True
# alpha =  0.002
#     17     30     17    -249.64501168  -188.06802717     -0.00162374      1.4e-02    2.1e-05   False   True
# alpha =  0.002
#     18     30     13    -249.64650851  -188.06952400     -0.00149683      1.4e-02    2.1e-05   False   True
# alpha =  0.002
#     19     30     16    -249.64794073  -188.07095621     -0.00143221      1.4e-02    1.8e-05   False   True
# alpha =  0.002
#     20     30     14    -249.64933085  -188.07234634     -0.00139012      1.5e-02    2.1e-05   False   True
# alpha =  0.002
#     21     30     10    -249.65068053  -188.07369602     -0.00134968      1.5e-02    2.1e-05   False   True
# alpha =  0.002
#     22     30     13    -249.65197794  -188.07499343     -0.00129741      1.4e-02    2.0e-05   False   True
# alpha =  0.002
#     23     30      9    -249.65321878  -188.07623426     -0.00124083      1.4e-02    2.1e-05   False   True
# alpha =  0.002
#     24     30      9    -249.65438554  -188.07740102     -0.00116676      1.3e-02    1.8e-05   False   True
#
# Lagrage sumdiff 6.3e-02 maxfdiff 2.1e-03
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    1.9999386  -20.65200023
#    2    1.9999257  -20.65199022
#    3    1.9996421  -11.41656669
#    4    1.9931393   -1.54477544
#    5    1.9927773   -1.50990709
#    6    1.9820747   -0.79051878
#    7    1.9815132   -0.77725905
#    8    1.9724700   -0.74439057
#    9    1.9836268   -0.69209639
#   10    1.9693032   -0.66204858
#   11    1.9668251   -0.64014935
#   12    0.0296299   -0.04621327
#   13    0.0035451   -0.00744085
#   14    0.0235910   -0.04030654
#   15    0.0071057   -0.01437886
#   16    0.0102254   -0.01532392
#   17    0.0061478   -0.01011302
#   18    0.0237270   -0.03934425
#   19    0.0038031   -0.00807581
#   20    0.0107962   -0.01822715
#   21    0.0076906   -0.01355870
#   22    0.0127226   -0.02038614
#   23    0.0052027   -0.00951063
#   24    0.0040950   -0.00916320
#   25    0.0031277   -0.00775268
#   26    0.0036150   -0.00868805
#   27    0.0032457   -0.00804340
#   28    0.0001795   -0.00246998
#   29    0.0001785   -0.00245497
#   30    0.0000381   -0.00080415
#   31    0.0000362   -0.00077747
#   32    0.0000382   -0.00081025
#   33    0.0000232   -0.00049769
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -188.0775019
#
#
# Elapsed Time:      89.50 (Seconds)
# True
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry C          line   138 file /home/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#     atoms 2 entry O          line   198 file /home/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#
# Number of basis functions                   (NBF)    = 28
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 7
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 3
# Dimension of the Nat. Orb. subspace         (NBF5)   = 28
# No. of electrons                                     = 14
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (SD/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      0     30     77    -135.03140351  -112.35238019 -10134.03140351      4.4e+00    1.6e-02   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      1     30    100    -135.52233382  -112.84331051     -0.49093032      2.6e-01    9.7e-06   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
#      2     30     14    -135.66143040  -112.98240709     -0.13909658      5.7e-02    1.7e-05   False   True
# alpha =  0.02
# Starting SD ... with alpha 0.02
# Final NOF Total Energy =    -112.9949174
#
#
# Elapsed Time:      72.34 (Seconds)
# True
# Number of basis functions                   (NBF)    = 28
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 7
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 3
# Dimension of the Nat. Orb. subspace         (NBF5)   = 28
# No. of electrons                                     = 14
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (RMSPROP/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
#      0     30    112    -135.31703087  -112.63800755 -10134.31703087      2.3e+01    1.1e-02   False   True
# alpha =  0.02
#      1     30    191    -135.43276255  -112.75373924     -0.11573169      5.9e+00    1.8e-05   False   True
# alpha =  0.02
#      2     30     46    -135.59142249  -112.91239918     -0.15865994      3.9e+00    1.1e-05   False   True
# alpha =  0.02
#      3     30     54    -135.66185582  -112.98283250     -0.07043333      1.9e+00    1.1e-05   False   True
# alpha =  0.02
#      4     30     39    -135.68821828  -113.00919497     -0.02636246      1.1e+00    1.2e-05   False   True
# alpha =  0.02
#      5     30     26    -135.69217968  -113.01315637     -0.00396140      9.3e-01    1.9e-05   False   True
# alpha =  0.02
#      6     30      0    -135.69236223  -113.01333892     -0.00018255      9.3e-01    1.9e-05   False   True
# alpha =  0.02
#      7     30      0    -135.69236223  -113.01333892      0.00000000      9.3e-01    1.9e-05   False   True
# alpha =  0.02
#      8     30      0    -135.69236223  -113.01333892      0.00000000      9.3e-01    1.9e-05   False   True
# alpha =  0.02
#      9     30      0    -135.69236223  -113.01333892      0.00000000      9.3e-01    1.9e-05   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 4.4e+00 maxfdiff 6.5e-02
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    1.9999917  -20.69674951
#    2    1.9998708  -11.37972065
#    3    1.9927038   -1.47907113
#    4    1.9839079   -0.83200017
#    5    1.9734334   -0.69729450
#    6    1.9649098   -0.67507090
#    7    1.9709232   -0.64531250
#    8    0.0217659   -0.03341688
#    9    0.0044468   -0.00784337
#   10    0.0028641   -0.00568649
#   11    0.0290777   -0.04136197
#   12    0.0035102   -0.00685355
#   13    0.0025023   -0.00573203
#   14    0.0249938   -0.03632423
#   15    0.0008102   -0.00169956
#   16    0.0007626   -0.00173469
#   17    0.0064253   -0.01040437
#   18    0.0053109   -0.00850355
#   19    0.0043559   -0.00748441
#   20    0.0032179   -0.00719515
#   21    0.0028986   -0.00684469
#   22    0.0011798   -0.00306617
#   23    0.0000451   -0.00058966
#   24    0.0000438   -0.00056096
#   25    0.0000402   -0.00051083
#   26    0.0000039   -0.00006904
#   27    0.0000024   -0.00005007
#   28    0.0000020   -0.00003388
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -113.0133389
#
#
# Elapsed Time:      29.91 (Seconds)
# True
# Number of basis functions                   (NBF)    = 28
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 7
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 3
# Dimension of the Nat. Orb. subspace         (NBF5)   = 28
# No. of electrons                                     = 14
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (ADAM/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.02
#      0     30    263    -135.43076541  -112.75174209 -10134.43076541      2.3e+01    1.1e-02   False   True
# alpha =  0.02
#      1     30    169    -135.65422188  -112.97519856     -0.22345647      6.1e-02    2.8e-05   False   True
# alpha =  0.02
#      2     30     80    -135.68709820  -113.00807488     -0.03287632      4.1e-02    1.9e-05   False   True
# alpha =  0.02
#      3     30    145    -135.69828646  -113.01926314     -0.01118826      4.7e-02    2.2e-05   False   True
# alpha =  0.02
#      4     30    113    -135.71158704  -113.03256372     -0.01330058      4.5e-02    2.2e-05   False   True
# alpha =  0.02
#      5     30     73    -135.71736275  -113.03833943     -0.00577571      3.9e-02    1.7e-05   False   True
# alpha =  0.02
#      6     30     45    -135.71942877  -113.04040546     -0.00206603      4.0e-02    1.9e-05   False   True
# alpha =  0.02
#      7     30     67    -135.72001729  -113.04099398     -0.00058852      2.6e-02    1.8e-05   False   True
# alpha =  0.02
#      8     30     28    -135.72014073  -113.04111742     -0.00012344      1.9e-02    1.9e-05   False   True
# alpha =  0.02
#      9     30     11    -135.72016236  -113.04113905     -0.00002163      1.8e-02    1.7e-05   False   True
# alpha =  0.02
#     10     30      4    -135.72017330  -113.04114999     -0.00001094      1.6e-02    2.0e-05   False   True
# alpha =  0.02
#     11     30     11    -135.72017881  -113.04115549     -0.00000551      1.6e-02    2.1e-05   False   True
# alpha =  0.02
#     12     30      4    -135.72018058  -113.04115727     -0.00000178      2.1e-02    1.7e-05   False   True
# alpha =  0.02
#     13     30      6    -135.72018366  -113.04116035     -0.00000308      1.6e-02    1.8e-05   False   True
# alpha =  0.02
#     14     30      0    -135.72018392  -113.04116060     -0.00000025      1.6e-02    1.8e-05   False   True
# alpha =  0.02
#     15     30      0    -135.72018392  -113.04116060      0.00000000      1.6e-02    1.8e-05   False   True
# alpha =  0.02
#     16     30      0    -135.72018392  -113.04116060      0.00000000      1.6e-02    1.8e-05   False   True
# alpha =  0.02
#     17     30      0    -135.72018392  -113.04116060      0.00000000      1.6e-02    1.8e-05   False   True
#
#
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
# !!!! Energy is not converging, if you are playing with alpha, is not a good value
# !!!! In any case check orbital and occupation gradients
# @@@@@@@@@@@ W A R N I N G @@@@@@@@@@@@@@@@@@@
#
#
#
# Lagrage sumdiff 7.0e-02 maxfdiff 1.3e-03
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    1.9999818  -20.68976302
#    2    1.9999025  -11.34572317
#    3    1.9925604   -1.50919015
#    4    1.9818031   -0.81856788
#    5    1.9782969   -0.68854835
#    6    1.9653098   -0.66782206
#    7    1.9661898   -0.60993820
#    8    0.0280654   -0.03823945
#    9    0.0031480   -0.00509188
#   10    0.0025968   -0.00479447
#   11    0.0287731   -0.04115743
#   12    0.0034864   -0.00678844
#   13    0.0024307   -0.00566649
#   14    0.0199390   -0.03117730
#   15    0.0008917   -0.00192281
#   16    0.0008725   -0.00187223
#   17    0.0086064   -0.01422315
#   18    0.0049581   -0.00916076
#   19    0.0046324   -0.00888094
#   20    0.0035687   -0.00749636
#   21    0.0027325   -0.00670381
#   22    0.0011384   -0.00291573
#   23    0.0000447   -0.00057207
#   24    0.0000443   -0.00056261
#   25    0.0000085   -0.00010864
#   26    0.0000144   -0.00029505
#   27    0.0000037   -0.00006981
#   28    0.0000001   -0.00000644
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =    -113.0411606
#
#
# Elapsed Time:      54.24 (Seconds)
# True
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry C          line   138 file /home/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#     atoms 2 entry O          line   198 file /home/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#
# Number of basis functions                   (NBF)    = 28
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 7
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 3
# Dimension of the Nat. Orb. subspace         (NBF5)   = 28
# No. of electrons                                     = 14
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (SD/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      0     30     55    -131.28187517  -108.60285185 -10130.28187517      7.4e+00    2.1e-02   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      1     30    150    -132.28459158  -109.60556826     -1.00271641      3.3e+00    2.2e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      2     30     45    -132.92329967  -110.24427635     -0.63870809      2.6e+00    1.5e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      3     30     54    -133.29378415  -110.61476083     -0.37048448      2.4e+00    1.3e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      4     30     38    -133.64828149  -110.96925817     -0.35449734      2.5e+00    1.5e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      5     30     29    -134.02155000  -111.34252669     -0.37326851      2.5e+00    2.0e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      6     30     26    -134.39887282  -111.71984951     -0.37732282      2.5e+00    1.8e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      7     30     25    -134.74285728  -112.06383396     -0.34398445      2.3e+00    1.5e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      8     30     22    -135.02339145  -112.34436814     -0.28053418      2.0e+00    1.5e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      9     30     19    -135.23228865  -112.55326533     -0.20889719      1.7e+00    2.1e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#     10     30     30    -135.37832867  -112.69930536     -0.14604003      1.4e+00    2.0e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#     11     30     12    -135.47650661  -112.79748329     -0.09817793      1.1e+00    1.2e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#     12     30     13    -135.54106896  -112.86204564     -0.06456235      9.3e-01    1.6e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#     13     30     13    -135.58307519  -112.90405188     -0.04200623      7.5e-01    1.4e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#     14     30     13    -135.61030476  -112.93128145     -0.02722957      6.0e-01    1.4e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#     15     30     14    -135.62797163  -112.94894831     -0.01766686      4.8e-01    1.6e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#     16     30      9    -135.63947564  -112.96045233     -0.01150402      3.9e-01    2.1e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#     17     30     25    -135.64700843  -112.96798512     -0.00753279      3.2e-01    1.3e-05   False   True
# ...
#    4    1.9721618   -0.60148581
#    5    1.9716117   -0.52392823
#    6    0.0165977   -0.02584941
#    7    0.0086292   -0.01433302
#    8    0.0031614   -0.00725729
#    9    0.0175436   -0.02740987
#   10    0.0071274   -0.01259216
#   11    0.0031673   -0.00727754
#   12    0.0064145   -0.01012101
#   13    0.0060261   -0.00911510
#   14    0.0010985   -0.00191198
#   15    0.0042506   -0.00914203
#   16    0.0008390   -0.00199602
#   17    0.0005105   -0.00129908
#   18    0.0000110   -0.00023625
#   19    0.0000104   -0.00022129
#   20    0.0000076   -0.00015725
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =     -76.2351602
#
#
# Elapsed Time:      56.54 (Seconds)
# True
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry O          line   198 file /home/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry H          line    22 file /home/pobmelat/miniconda3/envs/pynof2026/share/psi4/basis/cc-pvdz.gbs
#
# Number of basis functions                   (NBF)    = 24
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 5
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 3
# Dimension of the Nat. Orb. subspace         (NBF5)   = 20
# No. of electrons                                     = 10
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (SD/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      0     30     18     -81.26159730   -71.90698660 -10080.26159730      8.6e+00    1.6e-02   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      1     30    110     -82.01203835   -72.65742764     -0.75044104      2.7e+00    1.5e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
#      2     30     28     -82.38530542   -73.03069472     -0.37326707      1.8e+00    2.4e-05   False   True
# alpha =  0.002
# Starting SD ... with alpha 0.002
# No. considered Strongly Doubly occupied MOs (NDOC)   = 5
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 3
# Dimension of the Nat. Orb. subspace         (NBF5)   = 20
# No. of electrons                                     = 10
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (RMSPROP/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.002
#      0     30     72     -81.15426138   -71.79965068 -10080.15426138      8.6e+00    2.5e-02   False   True
# alpha =  0.002
#      1     30    144     -82.44549944   -73.09088874     -1.29123806      4.3e+00    1.0e-05   False   True
# alpha =  0.002
#      2     30     32     -83.42419739   -74.06958668     -0.97869795      3.7e+00    2.1e-05   False   True
# alpha =  0.002
#      3     30     22     -84.11792542   -74.76331472     -0.69372804      3.1e+00    1.7e-05   False   True
# alpha =  0.002
#      4     30     34     -84.62158850   -75.26697780     -0.50366308      2.5e+00    1.9e-05   False   True
# alpha =  0.002
#      5     30     43     -84.98075406   -75.62614336     -0.35916556      2.0e+00    1.7e-05   False   True
# alpha =  0.002
#      6     30     38     -85.21775002   -75.86313931     -0.23699595      1.5e+00    2.1e-05   False   True
# alpha =  0.002
#      7     30     30     -85.36170373   -76.00709303     -0.14395372      1.2e+00    1.6e-05   False   True
# alpha =  0.002
#      8     30     40     -85.44686610   -76.09225540     -0.08516237      9.7e-01    1.4e-05   False   True
# alpha =  0.002
#      9     30     19     -85.50434733   -76.14973662     -0.05748122      8.1e-01    2.0e-05   False   True
# alpha =  0.002
#     10     30     18     -85.54472322   -76.19011252     -0.04037590      6.4e-01    1.9e-05   False   True
# alpha =  0.002
#     11     30     20     -85.56921494   -76.21460424     -0.02449172      5.3e-01    1.8e-05   False   True
# alpha =  0.002
#     12     30     25     -85.58259295   -76.22798225     -0.01337801      4.5e-01    1.3e-05   False   True
# alpha =  0.002
#     13     30     20     -85.58711180   -76.23250110     -0.00451885      4.3e-01    1.4e-05   False   True
# alpha =  0.002
#     14     30     11     -85.58801091   -76.23340020     -0.00089910      4.2e-01    1.6e-05   False   True
# alpha =  0.002
#     15     30     10     -85.58853992   -76.23392922     -0.00052901      4.1e-01    1.9e-05   False   True
# alpha =  0.002
#     16     30      6     -85.58907371   -76.23446301     -0.00053379      3.6e-01    1.9e-05   False   True
# alpha =  0.002
#     17     30      8     -85.58956479   -76.23495409     -0.00049108      3.0e-01    1.7e-05   False   True
# alpha =  0.002
#     18     30      5     -85.59001550   -76.23540480     -0.00045071      2.3e-01    1.9e-05   False   True
# alpha =  0.002
#     19     30     11     -85.59028274   -76.23567204     -0.00026725      1.6e-01    1.8e-05   False   True
# alpha =  0.002
#     20     30      5     -85.59039098   -76.23578027     -0.00010823      1.6e-01    1.4e-05   False   True
# alpha =  0.002
#     21     30      5     -85.59062713   -76.23601642     -0.00023615      9.8e-02    1.2e-05   False   True
# alpha =  0.002
#     22     30      7     -85.59079204   -76.23618134     -0.00016491      7.5e-02    1.9e-05   False   True
# alpha =  0.002
#     23     30      3     -85.59092395   -76.23631324     -0.00013191      6.7e-02    2.6e-05   False   True
# alpha =  0.002
#     24     30      3     -85.59096413   -76.23635342     -0.00004018      8.4e-02    2.2e-05   False   True
#
# Lagrage sumdiff 3.3e-01 maxfdiff 7.0e-03
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    1.9999709  -20.57099115
#    2    1.9942774   -1.37560331
#    3    1.9756473   -0.72242750
#    4    1.9799525   -0.59714875
#    5    1.9724453   -0.55608979
#    6    0.0157472   -0.02519660
#    7    0.0082939   -0.01415909
#    8    0.0035136   -0.00746871
#    9    0.0106574   -0.01527972
#   10    0.0051200   -0.00889428
#   11    0.0042701   -0.00817921
#   12    0.0204596   -0.02983960
#   13    0.0034447   -0.00757553
#   14    0.0004484   -0.00101525
#   15    0.0041412   -0.00887003
#   16    0.0008928   -0.00193748
#   17    0.0006887   -0.00164596
#   18    0.0000113   -0.00023946
#   19    0.0000099   -0.00021609
#   20    0.0000079   -0.00016349
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =     -76.2363540
#
#
# Elapsed Time:      68.12 (Seconds)
# True
# Number of basis functions                   (NBF)    = 24
# Inactive Doubly occupied orbitals up too     (NO1)    = 0
# No. considered Strongly Doubly occupied MOs (NDOC)   = 5
# No. considered Strongly Singly occupied MOs (NSOC)   = 0
# No. of Weakly occ. per St. Doubly occ.  MOs (NCWO)   = 3
# Dimension of the Nat. Orb. subspace         (NBF5)   = 20
# No. of electrons                                     = 10
# Multiplicity                                         = 1
#
# No violations of the orthonormality
#
# PNOF8 Calculation (ADAM/Softmax Optimization)
# ==================
#
# Nitext  Nit_orb  Nit_occ      Eelec           Etot          Ediff        Grad_orb   Grad_occ Conv Orb Conv Occ
# alpha =  0.002
#      0     30     72     -80.82826247   -71.47365176 -10079.82826247      8.7e+00    2.9e-02   False   True
# alpha =  0.002
#      1     30    157     -82.02076472   -72.66615402     -1.19250225      4.3e+00    1.5e-05   False   True
# alpha =  0.002
#      2     30     51     -82.92180726   -73.56719656     -0.90104254      3.8e+00    1.4e-05   False   True
# alpha =  0.002
#      3     30     39     -83.64891720   -74.29430650     -0.72710994      3.3e+00    2.1e-05   False   True
# alpha =  0.002
#      4     30     57     -84.19979115   -74.84518045     -0.55087395      2.8e+00    1.1e-05   False   True
# alpha =  0.002
#      5     30     19     -84.61992974   -75.26531903     -0.42013858      2.3e+00    1.8e-05   False   True
# alpha =  0.002
#      6     30     41     -84.92034517   -75.56573447     -0.30041543      1.8e+00    1.3e-05   False   True
# alpha =  0.002
#      7     30     33     -85.12883781   -75.77422711     -0.20849264      1.5e+00    1.4e-05   False   True
# alpha =  0.002
#      8     30     25     -85.26409377   -75.90948307     -0.13525596      1.2e+00    1.2e-05   False   True
# alpha =  0.002
#      9     30     22     -85.35856302   -76.00395231     -0.09446925      1.1e+00    1.5e-05   False   True
# alpha =  0.002
#     10     30     15     -85.43029625   -76.07568554     -0.07173323      9.0e-01    1.9e-05   False   True
# alpha =  0.002
#     11     30     14     -85.49000194   -76.13539124     -0.05970569      7.4e-01    1.8e-05   False   True
# alpha =  0.002
#     12     30     18     -85.53311120   -76.17850049     -0.04310926      5.7e-01    8.2e-06   False   True
# alpha =  0.002
#     13     30     12     -85.56114283   -76.20653213     -0.02803164      4.1e-01    1.8e-05   False   True
# alpha =  0.002
#     14     30     10     -85.57949775   -76.22488705     -0.01835492      2.6e-01    1.7e-05   False   True
# alpha =  0.002
#     15     30     18     -85.58873782   -76.23412711     -0.00924006      1.2e-01    2.1e-05   False   True
# alpha =  0.002
#     16     30      9     -85.59115365   -76.23654294     -0.00241583      1.5e-02    2.0e-05   False   True
# alpha =  0.002
#     17     30      5     -85.59146888   -76.23685818     -0.00031524      4.4e-03    2.0e-05   False   True
# alpha =  0.002
#     18     30      6     -85.59178004   -76.23716934     -0.00031116      4.6e-03    2.0e-05   False   True
# alpha =  0.002
#     19     30     25     -85.59216225   -76.23755155     -0.00038221      4.9e-03    1.1e-05   False   True
# alpha =  0.002
#     20     30      6     -85.59258375   -76.23797304     -0.00042149      5.0e-03    1.8e-05   False   True
# alpha =  0.002
#     21     30      9     -85.59300234   -76.23839164     -0.00041860      5.0e-03    2.5e-05   False   True
# alpha =  0.002
#     22     30     10     -85.59339649   -76.23878578     -0.00039414      4.9e-03    1.3e-05   False   True
# alpha =  0.002
#     23     30     11     -85.59374909   -76.23913839     -0.00035260      4.7e-03    2.2e-05   False   True
# alpha =  0.002
#     24     30      5     -85.59404674   -76.23943604     -0.00029765      4.4e-03    1.2e-05   False   True
#
# Lagrage sumdiff 1.4e-02 maxfdiff 5.5e-04
#
# RESULTS OF THE OCCUPATION OPTIMIZATION
# ========================================
#  Idx        n        E (Hartree)
#    1    1.9999719  -20.56586545
#    2    1.9946317   -1.34872142
#    3    1.9737068   -0.71036456
#    4    1.9720955   -0.65413597
#    5    1.9775191   -0.53833284
#    6    0.0124528   -0.01699466
#    7    0.0052896   -0.00923264
#    8    0.0047386   -0.00855436
#    9    0.0182416   -0.02771809
#   10    0.0062630   -0.01131074
#   11    0.0033999   -0.00744106
#   12    0.0218153   -0.03060653
#   13    0.0038227   -0.00767590
#   14    0.0006553   -0.00138020
#   15    0.0040020   -0.00867593
#   16    0.0008584   -0.00191969
#   17    0.0005079   -0.00127629
#   18    0.0000113   -0.00023475
#   19    0.0000087   -0.00019284
#   20    0.0000081   -0.00016896
#
# ----------------
#  Final Energies
# ----------------
# Final NOF Total Energy =     -76.2394428
#
#
# Elapsed Time:      69.44 (Seconds)
# True
# Time for CO2: 457.8015 s
# Time for CO: 379.3235 s
# Time for H2O: 353.4587 s
# Total Time: 1190.5839891433716
